# %%
import pandas as pd
import numpy as np

# %%
gene_nt = pd.read_csv(r"C:\Users\ntama\Downloads\GSE96058_transcript_expression_3273_samples_and_136_replicates.csv.gz")

# %%
gene_nt.head()
# Out:
#    Unnamed: 0            F1       F2        F3        F4        F5        F6  \
# 0  uc001aaa.3  0.000000e+00  0.00000  0.000000  0.000000  0.000000  0.000000
# 1  uc001aab.3  0.000000e+00  0.00000  0.000000  0.000000  0.000000  0.000000
# 2  uc010nxq.1  0.000000e+00  0.00000  0.000000  0.000000  0.000000  0.000000
# 3  uc031tla.1  0.000000e+00  0.00000  0.000000  0.000000  0.000000  0.000000
# 4  uc001aae.4  1.310780e-10  0.08373  0.000443  0.252492  0.000003  0.091793
#
#              F7            F8            F9  ...  F2974repl  F3006repl  \
# 0  0.000000e+00  0.000000e+00  0.000000e+00  ...   0.000000   0.000000
# 1  0.000000e+00  0.000000e+00  0.000000e+00  ...   0.000000   0.000000
# 2  2.153770e-02  0.000000e+00  0.000000e+00  ...   0.000000   0.000000
# 3  0.000000e+00  0.000000e+00  0.000000e+00  ...   0.000000   0.000000
# 4  5.662270e-19  4.634890e-11  2.631560e-21  ...   0.000004   0.000244
#
#       F3028repl  F3057repl     F3058repl     F3085repl     F3127repl  \
# ...

# %%
print(np.min(gene_nt['F2000']))
# Out:
# 0.0
